# %%
import polars as pl

# %%
df = pl.read_csv('datasets/train.csv')

# %%
df['category'].value_counts()
# Out:
# shape: (5, 2)
# ┌───────────────┬───────┐
# │ category      ┆ count │
# │ ---           ┆ ---   │
# │ str           ┆ u32   │
# ╞═══════════════╪═══════╡
# │ SCIENCE       ┆ 713   │
# │ CULTURE       ┆ 963   │
# │ TECHNOLOGY    ┆ 2441  │
# │ LIFE_ARTS     ┆ 709   │
# │ STACKOVERFLOW ┆ 1253  │
# └───────────────┴───────┘

# %%
df.shape
# Out:
# (6079, 41)
