# %%
# imports
import polars as pl
import matplotlib.pyplot as plt

from pathlib import Path

# %%
FILE_PATH

# %%
pl.read_csv('datasets/twitter_training.csv')
# Out:
# shape: (74_682, 4)
# ┌──────┬─────────────┬──────────┬─────────────────────────────────┐
# │ id   ┆ campo       ┆ class    ┆ text                            │
# │ ---  ┆ ---         ┆ ---      ┆ ---                             │
# │ i64  ┆ str         ┆ str      ┆ str                             │
# ╞══════╪═════════════╪══════════╪═════════════════════════════════╡
# │ 2401 ┆ Borderlands ┆ Positive ┆ im getting on borderlands and … │
# │ 2401 ┆ Borderlands ┆ Positive ┆ I am coming to the borders and… │
# │ 2401 ┆ Borderlands ┆ Positive ┆ im getting on borderlands and … │
# │ 2401 ┆ Borderlands ┆ Positive ┆ im coming on borderlands and i… │
# │ 2401 ┆ Borderlands ┆ Positive ┆ im getting on borderlands 2 an… │
# │ …    ┆ …           ┆ …        ┆ …                               │
# │ 9200 ┆ Nvidia      ┆ Positive ┆ Just realized that the Windows… │
# │ 9200 ┆ Nvidia      ┆ Positive ┆ Just realized that my Mac wind… │
# ...

# %%
print(pl.read_csv('datasets/twitter_training.csv')['class'].value_counts(normalize=True))
# Out:
# shape: (4, 2)
# ┌────────────┬────────────┐
# │ class      ┆ proportion │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ Neutral    ┆ 0.24528    │
# │ Irrelevant ┆ 0.173937   │
# │ Negative   ┆ 0.30184    │
# │ Positive   ┆ 0.278943   │
# └────────────┴────────────┘
